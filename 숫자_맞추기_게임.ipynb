# %% [markdown]
# <a href="https://colab.research.google.com/github/a01026631075-create/2025_opensource/blob/main/%EC%88%AB%EC%9E%90_%EB%A7%9E%EC%B6%94%EA%B8%B0_%EA%B2%8C%EC%9E%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def play():
    target = random.randint(1, 100)
    attempts = 0
    print("1에서 100 사이의 숫자를 맞춰보세요!")
    while True:
        attempts += 1
        try:
            guess = int(input(f"[{attempts}] 추측: "))
        except ValueError:
            print("정수를 입력하세요.")
            continue
        if guess < target:
            print("더 큽니다 ↑")
        elif guess > target:
            print("더 작습니다 ↓")
        else:
            print(f"정답! {attempts}번 만에 맞췄습니다 🎉")
            break

if __name__ == "__main__":
    play()
# Out:
# 1에서 100 사이의 숫자를 맞춰보세요!
